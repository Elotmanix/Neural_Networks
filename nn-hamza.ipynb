# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import *
from sklearn.model_selection import *
from sklearn.tree import *
from sklearn.ensemble import *
from numpy import random
from sklearn.preprocessing import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('/kaggle/input/basic-datasets/heart.csv')
df.head()

# %%
y=df['output'].values
X=df.drop(['output'],axis=1).values

scaler=MinMaxScaler()
X= scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
model = Sequential()
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train,validation_data=(X_test,y_test), epochs=200, verbose=1)

# %%
y=df["output"]
X=df.drop(["output"],axis=1)
X=MinMaxScaler().fit_transform(X)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
model = Sequential()
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
histoy=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=500,verbose=0)

# %%
plt.plot(range(200), history.history['accuracy'], c='blue')
plt.plot(range(200), history.history['val_accuracy'], c='red')

# %%
y_hat = model.predict(X_test)

# %%
y_hat.reshape(-1)

# %%
df=pd.read_csv('/kaggle/input/basic-datasets/iris.csv')
df.head()

# %%
np.unique(df.species)

# %%
df = pd.get_dummies(df, columns=['species'])
df.head()

# %%
y=df[['species_setosa','species_versicolor','species_virginica']].values
X=df.drop(['species_setosa','species_versicolor','species_virginica'],axis=1).values

scaler=MinMaxScaler()
X= scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
model = Sequential()
model.add(Dense(3, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train,validation_data=(X_test,y_test), epochs=200, verbose=1)

# %%
plt.plot(range(200), history.history['accuracy'], c='blue')
plt.plot(range(200), history.history['val_accuracy'], c='red')

# %% [markdown]
# # autre methode

# %%
df=pd.read_csv('/kaggle/input/basic-datasets/iris.csv')
df.head()

# %%
np.unique(df.species)

# %%
df['species']=df['species'].map({'setosa':0,'versicolor':1,'virginica':2})

# %%
y=df[['species']].values
X=df.drop(['species'],axis=1).values

scaler=MinMaxScaler()
X= scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
model = Sequential()
model.add(Dense(3, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train,validation_data=(X_test,y_test), epochs=200, verbose=1)

# %%
plt.plot(range(200), history.history['accuracy'], c='blue')
plt.plot(range(200), history.history['val_accuracy'], c='red')

# %%
y_hat = model.predict(X_test)

# %%
y_hat.argmax(axis=1)

# %%
df=pd.read_csv('/kaggle/input/sign-language-mnist/sign_mnist_train/sign_mnist_train.csv')
df.head()

# %%
np.unique(df.label)

# %%
y=df[['label']].values
X=df.drop(['label'],axis=1).values

# %%
X[0]

# %%
chr(65)

# %%
for i in range(10):
    plt.imshow(X[i].reshape(28,28),cmap='Greys')
    plt.title(chr(y[i]+65))
    plt.show

# %%
scaler=MinMaxScaler()
X= scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
model = Sequential()
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(25, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train,validation_data=(X_test,y_test), epochs=200, verbose=1)

# %%
y_hat = model.predict(X_test).argmax(axis=1)

# %%
plt.plot(range(200), history.history['accuracy'], c='blue')
plt.plot(range(200), history.history['val_accuracy'], c='red')
print('accuracy :',accuracy_score(y_test,y_hat))
print(classification_report(y_test,y_hat))

# %%
confusion_matrix(y_test,y_hat)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_hat = model.predict(X_test)

# %%
print('accuracy :',accuracy_score(y_test,y_hat))
print(classification_report(y_test,y_hat))

# %%
confusion_matrix(y_test,y_hat)
